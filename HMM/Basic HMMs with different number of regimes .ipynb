# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import statsmodels.api as sm
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
def reReadData():
  df=pd.read_csv('gdrive/My Drive/Data_Version_4.csv',header=0, index_col=0, 
                infer_datetime_format=True, parse_dates=['Date'])
  df['log_ret'] = np.log(df['Russell3000_Adj_Close']) - np.log(df['Russell3000_Adj_Close'].shift(1))
  #df = df.dropna()
  #df = df[train_start:test_end]
  #df_train, df_test = df[train_start:train_end],df[train_end:test_end]
  return df


def plotProb_train(model):
  bear_regime = 0 if model.params['const[0]']<model.params['const[1]'] else 1

  fig, axes = plt.subplots(2, figsize=(15, 15))

  ax = axes[0]
  ax.plot(df_train.index, df_train['Russell_Close'])
  ax.set(title='Russell_Close')
  
  ax = axes[1]
  ax.plot(df_train.index, model.filtered_marginal_probabilities[bear_regime])
  ax.set(title='Filtered probability of bear_regime')

  plt.show()


def plotProb_test(model):
  bear_regime = 0 if model.params['const[0]']<model.params['const[1]'] else 1

  fig, axes = plt.subplots(2, figsize=(15, 15))

  ax = axes[0]
  ax.plot(df_test.index, df_test['Russell_Close'])
  ax.set(title='Russell_Close')
  
  ax = axes[1]
  ax.plot(df_test.index, model.filtered_marginal_probabilities[bear_regime])
  ax.set(title='Filtered probability of bear_regime')

  plt.show()


def labeling(model,threshold1, threshold2):
  bear_regime = 0 if model.params['const[0]'] < model.params['const[1]'] else 1

  label_filtered = []
  
  for i in model.filtered_marginal_probabilities[bear_regime].values:
    if i >= threshold1:
      app = -1
    elif i >= threshold2:
      app = 0
    else:
      app = 1
    label_filtered.append(app)

  label_filtered= np.array(label_filtered)
  
  return label_filtered


def duration(label):

  duration_bull = []
  duration_static = []
  duration_bear = []

  count,prev,trade = 1,1,0

  for i in label:
    if i == prev:
      count+=1
    else:
      trade+=1
      if prev == 1:
        duration_bull.append(count)
        count = 1
      elif prev == 0:
        duration_static.append(count)
        count = 1
      else:
        duration_bear.append(count)
        count = 1
    prev = i
    
  if prev == 1:
    duration_bull.append(count)
  elif prev == 0:
    duration_static.append(count)
  else:
    duration_bear.append(count)

  duration_bull = pd.DataFrame(duration_bull)
  duration_static = pd.DataFrame(duration_static)
  duration_bear = pd.DataFrame(duration_bear)

  return duration_bull, duration_static, duration_bear,trade


def label_train_logret(label):
  return (df_train['log_ret'] * label).sum()

def label_test_logret(label):
  return (df_test['log_ret'] * label).sum()



def Search_train(model, duration_static, duration_bear):
  threshold1, threshold2, record =0,0,0
  for i in range(1,101):
    for j in range(i):
      label_filtered = labeling(model,i/100, j/100)
      if ( (duration(label_filtered))[1].mean().values >= duration_static ):
        if ( (duration(label_filtered))[2].mean().values >= duration_bear ) :
          if ( (df_train['log_ret'] * label_filtered).sum() >= record ):
            threshold1, threshold2, record = i,j,(df_train['log_ret'] * label_filtered).sum()
  return threshold1/100, threshold2/100

# %%
train_start = '2000-01-01'
train_end = '2017-12-31'
test_end = '2022-01-25'

# %%
#df,df_train,df_test = reReadData()
df = reReadData()
print(df)
# Out:
#              PX_LAST     PX_VOLUME  ...  Russell3000_Volume   log_ret
# Date                                ...
# 1990-01-02    585.41           NaN  ...                 0.0       NaN
# 1990-01-03    585.05           NaN  ...                 0.0 -0.000999
# 1990-01-04    580.97           NaN  ...                 0.0 -0.006316
# 1990-01-05    575.74           NaN  ...                 0.0 -0.010058
# 1990-01-08    577.78           NaN  ...                 0.0  0.003448
# ...              ...           ...  ...                 ...       ...
# 2022-01-19  14547.22  1.322548e+09  ...                 0.0 -0.010180
# 2022-01-20  14378.11  1.355285e+09  ...                 0.0 -0.011763
# 2022-01-21  14099.17  1.917342e+09  ...                 0.0 -0.019599
# 2022-01-24  14173.27  2.178968e+09  ...                 0.0  0.000000
# 2022-01-25  13982.41  1.611222e+09  ...                 0.0  0.000000
#
# [8090 rows x 45 columns]

# %%
for k in [5,10,15]:
  name = 'log_ret_MA'+str(k)
  df[name] = df['log_ret'].rolling(k).mean()
  name1 = 'log_ret_EWMA'+str(k)
  df[name1] = df['log_ret'].ewm(span=k).mean()  
df
# Out:
#              PX_LAST     PX_VOLUME  ...  log_ret_MA15  log_ret_EWMA15
# Date                                ...
# 1990-01-02    585.41           NaN  ...           NaN             NaN
# 1990-01-03    585.05           NaN  ...           NaN       -0.000999
# 1990-01-04    580.97           NaN  ...           NaN       -0.003835
# 1990-01-05    575.74           NaN  ...           NaN       -0.006192
# 1990-01-08    577.78           NaN  ...           NaN       -0.003280
# ...              ...           ...  ...           ...             ...
# 2022-01-19  14547.22  1.322548e+09  ...     -0.004039       -0.004643
# 2022-01-20  14378.11  1.355285e+09  ...     -0.004907       -0.005533
# 2022-01-21  14099.17  1.917342e+09  ...     -0.006071       -0.007291
# 2022-01-24  14173.27  2.178968e+09  ...     -0.005886       -0.006380
# 2022-01-25  13982.41  1.611222e+09  ...     -0.006286       -0.005582
#
# [8090 rows x 51 columns]

# %%
df = df.iloc[15: , :]

# %%
#df = df.dropna()
df = df[train_start:test_end]
df_train, df_test = df[train_start:train_end],df[train_end:test_end]
print(df,df_train,df_test)
# Out:
#              PX_LAST     PX_VOLUME  ...  log_ret_MA15  log_ret_EWMA15
# Date                                ...
# 2000-01-03   2909.89  1.748611e+09  ...      0.001836        0.001467
# 2000-01-04   2795.36  1.805332e+09  ...     -0.000677       -0.003646
# 2000-01-05   2802.51  2.100967e+09  ...      0.000168       -0.002977
# 2000-01-06   2784.07  1.972651e+09  ...     -0.000207       -0.002664
# 2000-01-07   2878.11  2.151953e+09  ...      0.001289        0.001013
# ...              ...           ...  ...           ...             ...
# 2022-01-19  14547.22  1.322548e+09  ...     -0.004039       -0.004643
# 2022-01-20  14378.11  1.355285e+09  ...     -0.004907       -0.005533
# 2022-01-21  14099.17  1.917342e+09  ...     -0.006071       -0.007291
# 2022-01-24  14173.27  2.178968e+09  ...     -0.005886       -0.006380
# 2022-01-25  13982.41  1.611222e+09  ...     -0.006286       -0.005582
#
# [5558 rows x 51 columns]             PX_LAST     PX_VOLUME  ...  log_ret_MA15  log_ret_EWMA15
# Date                               ...
# 2000-01-03  2909.89  1.748611e+09  ...      0.001836        0.001467
# 2000-01-04  2795.36  1.805332e+09  ...     -0.000677       -0.003646
# 2000-01-05  2802.51  2.100967e+09  ...      0.000168       -0.002977
# 2000-01-06  2784.07  1.972651e+09  ...     -0.000207       -0.002664
# 2000-01-07  2878.11  2.151953e+09  ...      0.001289        0.001013
# ...             ...           ...  ...           ...             ...
# 2017-12-22  8185.44  7.605023e+08  ...      0.000946        0.001144
# 2017-12-26  8179.36  6.517333e+08  ...      0.000986        0.000902
# 2017-12-27  8185.85  6.629423e+08  ...      0.001330        0.000881
# 2017-12-28  8205.06  6.140417e+08  ...      0.001523        0.001029
# 2017-12-29  8160.88  9.049341e+08  ...      0.000909        0.000217
#
# [4534 rows x 51 columns]              PX_LAST     PX_VOLUME  ...  log_ret_MA15  log_ret_EWMA15
# Date                                ...
# 2018-01-02   8228.76  1.002174e+09  ...      0.001117        0.001220
# 2018-01-03   8276.86  9.976070e+08  ...      0.001328        0.001796
# 2018-01-04   8308.38  1.080767e+09  ...      0.001511        0.002024
# 2018-01-05   8361.79  9.552642e+08  ...      0.001942        0.002572
# 2018-01-08   8377.28  1.022988e+09  ...      0.002385        0.002480
# ...              ...           ...  ...           ...             ...
# 2022-01-19  14547.22  1.322548e+09  ...     -0.004039       -0.004643
# 2022-01-20  14378.11  1.355285e+09  ...     -0.004907       -0.005533
# 2022-01-21  14099.17  1.917342e+09  ...     -0.006071       -0.007291
# 2022-01-24  14173.27  2.178968e+09  ...     -0.005886       -0.006380
# 2022-01-25  13982.41  1.611222e+09  ...     -0.006286       -0.005582
#
# [1024 rows x 51 columns]

# %%
from statsmodels.tsa.stattools import adfuller
adfuller(df_train['Russell3000_Adj_Close'])
# Out:
# (1.190895094144477,
#  0.9959223692556765,
#  18,
#  4515,
#  {'1%': -3.431799174247188,
#   '10%': -2.567110868692889,
#   '5%': -2.8621803631732403},
#  32305.791435624727)

# %%
adfuller(df_train['log_ret'])
# Out:
# (-15.310939694230568,
#  4.187362600147997e-28,
#  20,
#  4513,
#  {'1%': -3.4317998168351687,
#   '10%': -2.5671110198147815,
#   '5%': -2.8621806470517406},
#  -26857.584095841747)

# %%
adfuller(df_train['log_ret_EWMA5'])
# Out:
# (-13.212160923173911,
#  1.0417491651649047e-24,
#  21,
#  4512,
#  {'1%': -3.4318001383429073,
#   '10%': -2.5671110954259877,
#   '5%': -2.862180789085396},
#  -36746.45075161783)

# %%
duration_static, duration_bear = 0, 0

# %% [markdown]
# ## Basic HMM with log return

# %%
hmm1 = sm.tsa.MarkovRegression(endog=df_train['log_ret'], k_regimes=2,trend='c',switching_variance=False)
hmm1_results = hmm1.fit(search_reps = 100)
print(hmm1_results.summary())
hmm1 = sm.tsa.MarkovRegression(endog=df_train['log_ret'], k_regimes=2,trend='c',switching_variance=True)
hmm1_results = hmm1.fit(search_reps = 100)
print(hmm1_results.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                         Markov Switching Model Results
# ==============================================================================
# Dep. Variable:                log_ret   No. Observations:                 4534
# Model:               MarkovRegression   Log Likelihood               13682.360
# Date:                Mon, 14 Feb 2022   AIC                         -27354.719
# Time:                        21:45:00   BIC                         -27322.622
# Sample:                             0   HQIC                        -27343.414
#                                - 4534
# Covariance Type:               approx
#                              Regime 0 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0440      0.003    -16.123      0.000      -0.049      -0.039
#                              Regime 1 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0008      0.000      4.331      0.000       0.000       0.001
#                            Non-switching parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         0.0001   2.94e-06     42.538      0.000       0.000       0.000
#                          Regime transition parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p[0->0]        0.1979      0.069      2.868      0.004       0.063       0.333
# p[1->0]        0.0112      0.002      5.228      0.000       0.007       0.015
# ==============================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                         Markov Switching Model Results
# ==============================================================================
# Dep. Variable:                log_ret   No. Observations:                 4534
# Model:               MarkovRegression   Log Likelihood               14373.200
# Date:                Mon, 14 Feb 2022   AIC                         -28734.399
# Time:                        21:45:05   BIC                         -28695.883
# Sample:                             0   HQIC                        -28720.833
#                                - 4534
# Covariance Type:               approx
#                              Regime 0 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0010      0.001     -1.922      0.055      -0.002    2.07e-05
# sigma2         0.0004   1.87e-05     20.594      0.000       0.000       0.000
#                              Regime 1 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0007      0.000      4.787      0.000       0.000       0.001
# sigma2      5.466e-05   2.07e-06     26.366      0.000    5.06e-05    5.87e-05
#                          Regime transition parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p[0->0]        0.9813      0.005    205.980      0.000       0.972       0.991
# p[1->0]        0.0079      0.002      3.841      0.000       0.004       0.012
# ==============================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.

# %%
hmm1 = sm.tsa.MarkovRegression(endog=df_train['log_ret'], k_regimes=3,trend='c',switching_variance=False)
hmm1_results = hmm1.fit(search_reps = 100)
print(hmm1_results.summary())
hmm1 = sm.tsa.MarkovRegression(endog=df_train['log_ret'], k_regimes=3,trend='c',switching_variance=True)
hmm1_results = hmm1.fit(search_reps = 100)
print(hmm1_results.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                         Markov Switching Model Results
# ==============================================================================
# Dep. Variable:                log_ret   No. Observations:                 4534
# Model:               MarkovRegression   Log Likelihood               13960.147
# Date:                Mon, 14 Feb 2022   AIC                         -27900.293
# Time:                        21:45:16   BIC                         -27836.100
# Sample:                             0   HQIC                        -27877.683
#                                - 4534
# Covariance Type:               approx
#                              Regime 0 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0353      0.002    -20.659      0.000      -0.039      -0.032
#                              Regime 1 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0394      0.002     22.756      0.000       0.036       0.043
#                              Regime 2 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0004      0.000      2.496      0.013    8.78e-05       0.001
#                            Non-switching parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2       9.48e-05   2.57e-06     36.861      0.000    8.98e-05    9.98e-05
#                          Regime transition parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p[0->0]        0.2738      0.054      5.043      0.000       0.167       0.380
# p[1->0]        0.2174      0.065      3.365      0.001       0.091       0.344
# p[2->0]        0.0154      0.003      5.860      0.000       0.010       0.021
# p[0->1]        0.2675      0.050      5.310      0.000       0.169       0.366
# p[1->1]        0.0952      0.039      2.465      0.014       0.019       0.171
# p[2->1]        0.0087      0.002      4.323      0.000       0.005       0.013
# ==============================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/regime_switching/markov_switching.py:1478: EstimationWarning: Invalid regime transition probabilities estimated in EM iteration; probabilities have been re-scaled to continue estimation.
#   EstimationWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/regime_switching/markov_switching.py:1478: EstimationWarning: Invalid regime transition probabilities estimated in EM iteration; probabilities have been re-scaled to continue estimation.
#   EstimationWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/regime_switching/markov_switching.py:1478: EstimationWarning: Invalid regime transition probabilities estimated in EM iteration; probabilities have been re-scaled to continue estimation.
#   EstimationWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/regime_switching/markov_switching.py:1478: EstimationWarning: Invalid regime transition probabilities estimated in EM iteration; probabilities have been re-scaled to continue estimation.
#   EstimationWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/regime_switching/markov_switching.py:1478: EstimationWarning: Invalid regime transition probabilities estimated in EM iteration; probabilities have been re-scaled to continue estimation.
#   EstimationWarning)
#                         Markov Switching Model Results
# ==============================================================================
# Dep. Variable:                log_ret   No. Observations:                 4534
# Model:               MarkovRegression   Log Likelihood               14406.921
# Date:                Mon, 14 Feb 2022   AIC                         -28789.842
# Time:                        21:45:24   BIC                         -28712.809
# Sample:                             0   HQIC                        -28762.709
#                                - 4534
# Covariance Type:               approx
#                              Regime 0 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0007      0.001     -1.105      0.269      -0.002       0.001
# sigma2         0.0004   2.31e-05     18.357      0.000       0.000       0.000
#                              Regime 1 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0012      0.000      7.447      0.000       0.001       0.002
# sigma2      4.884e-05   2.68e-06     18.221      0.000    4.36e-05    5.41e-05
#                              Regime 2 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0167      0.001    -13.327      0.000      -0.019      -0.014
# sigma2      4.133e-05        nan        nan        nan         nan         nan
#                          Regime transition parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p[0->0]        0.9804        nan        nan        nan         nan         nan
# p[1->0]        0.0003      0.001      0.409      0.682      -0.001       0.002
# p[2->0]        0.1450      0.057      2.529      0.011       0.033       0.257
# p[0->1]        0.0196        nan        nan        nan         nan         nan
# p[1->1]        0.9568      0.009    104.294      0.000       0.939       0.975
# p[2->1]        0.7936      0.042     18.781      0.000       0.711       0.876
# ==============================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:1286: RuntimeWarning: invalid value encountered in sqrt
#   bse_ = np.sqrt(np.diag(self.cov_params()))

# %%
hmm1 = sm.tsa.MarkovRegression(endog=df_train['log_ret'], k_regimes=4,trend='c',switching_variance=False)
hmm1_results = hmm1.fit(search_reps = 100)
print(hmm1_results.summary())
hmm1 = sm.tsa.MarkovRegression(endog=df_train['log_ret'], k_regimes=4,trend='c',switching_variance=True)
hmm1_results = hmm1.fit(search_reps = 100)
print(hmm1_results.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:1286: RuntimeWarning: invalid value encountered in sqrt
#   bse_ = np.sqrt(np.diag(self.cov_params()))
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                         Markov Switching Model Results
# ==============================================================================
# Dep. Variable:                log_ret   No. Observations:                 4534
# Model:               MarkovRegression   Log Likelihood               14080.430
# Date:                Mon, 14 Feb 2022   AIC                         -28126.859
# Time:                        21:45:40   BIC                         -28017.730
# Sample:                             0   HQIC                        -28088.421
#                                - 4534
# Covariance Type:               approx
#                              Regime 0 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0281      0.001     20.488      0.000       0.025       0.031
#                              Regime 1 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0011        nan        nan        nan         nan         nan
#                              Regime 2 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0260      0.001    -22.550      0.000      -0.028      -0.024
#                              Regime 3 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0004      0.000      2.616      0.009       0.000       0.001
#                            Non-switching parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      9.182e-05   2.36e-06     38.905      0.000    8.72e-05    9.64e-05
#                          Regime transition parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p[0->0]        0.1165      0.035      3.285      0.001       0.047       0.186
# p[1->0]        0.4549        nan        nan        nan         nan         nan
# p[2->0]        0.2356      0.037      6.352      0.000       0.163       0.308
# p[3->0]        0.0001        nan        nan        nan         nan         nan
# p[0->1]        0.5213        nan        nan        nan         nan         nan
# p[1->1]        0.0004      0.015      0.025      0.980      -0.029       0.029
# p[2->1]        0.5288        nan        nan        nan         nan         nan
# p[3->1]        0.0003        nan        nan        nan         nan         nan
# p[0->2]        0.2319      0.044      5.254      0.000       0.145       0.318
# p[1->2]        0.5424        nan        nan        nan         nan         nan
# p[2->2]        0.2273      0.037      6.182      0.000       0.155       0.299
# p[3->2]        0.0057        nan        nan        nan         nan         nan
# ==============================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/regime_switching/markov_switching.py:1478: EstimationWarning: Invalid regime transition probabilities estimated in EM iteration; probabilities have been re-scaled to continue estimation.
#   EstimationWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/regime_switching/markov_switching.py:1478: EstimationWarning: Invalid regime transition probabilities estimated in EM iteration; probabilities have been re-scaled to continue estimation.
#   EstimationWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/regime_switching/markov_switching.py:1478: EstimationWarning: Invalid regime transition probabilities estimated in EM iteration; probabilities have been re-scaled to continue estimation.
#   EstimationWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/regime_switching/markov_switching.py:1478: EstimationWarning: Invalid regime transition probabilities estimated in EM iteration; probabilities have been re-scaled to continue estimation.
#   EstimationWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/regime_switching/markov_switching.py:1478: EstimationWarning: Invalid regime transition probabilities estimated in EM iteration; probabilities have been re-scaled to continue estimation.
#   EstimationWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#                         Markov Switching Model Results
# ==============================================================================
# Dep. Variable:                log_ret   No. Observations:                 4534
# Model:               MarkovRegression   Log Likelihood               14593.152
# Date:                Mon, 14 Feb 2022   AIC                         -29146.304
# Time:                        21:46:01   BIC                         -29017.917
# Sample:                             0   HQIC                        -29101.083
#                                - 4534
# Covariance Type:               approx
#                              Regime 0 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0009      0.000      6.680      0.000       0.001       0.001
# sigma2      3.269e-05   1.58e-06     20.707      0.000    2.96e-05    3.58e-05
#                              Regime 1 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0020      0.000      6.118      0.000       0.001       0.003
# sigma2         0.0001   7.75e-06     13.647      0.000    9.05e-05       0.000
#                              Regime 2 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0011      0.001     -0.929      0.353      -0.003       0.001
# sigma2         0.0007    5.3e-05     13.178      0.000       0.001       0.001
#                              Regime 3 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0157      0.001    -13.520      0.000      -0.018      -0.013
# sigma2      6.218e-05   1.23e-05      5.072      0.000    3.82e-05    8.62e-05
#                          Regime transition parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p[0->0]        0.9786      0.006    160.173      0.000       0.967       0.991
# p[1->0]        0.0282      0.006      4.958      0.000       0.017       0.039
# p[2->0]     7.305e-07        nan        nan        nan         nan         nan
# p[3->0]     3.023e-07      0.032   9.31e-06      1.000      -0.064       0.064
# p[0->1]     6.223e-07      0.017   3.72e-05      1.000      -0.033       0.033
# p[1->1]        0.8437      0.016     53.927      0.000       0.813       0.874
# p[2->1]        0.0290      0.019      1.494      0.135      -0.009       0.067
# p[3->1]        0.9397      0.084     11.122      0.000       0.774       1.105
# p[0->2]     3.323e-05      0.001      0.022      0.982      -0.003       0.003
# p[1->2]        0.0007      0.004      0.152      0.879      -0.008       0.009
# p[2->2]        0.9710        nan        nan        nan         nan         nan
# p[3->2]        0.0566      0.034      1.673      0.094      -0.010       0.123
# ==============================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:1286: RuntimeWarning: invalid value encountered in sqrt
#   bse_ = np.sqrt(np.diag(self.cov_params()))

# %%
hmm1 = sm.tsa.MarkovRegression(endog=df_train['log_ret'], k_regimes=5,trend='c',switching_variance=False)
hmm1_results = hmm1.fit(search_reps = 100)
print(hmm1_results.summary())
hmm1 = sm.tsa.MarkovRegression(endog=df_train['log_ret'], k_regimes=5,trend='c',switching_variance=True)
hmm1_results = hmm1.fit(search_reps = 100)
print(hmm1_results.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/regime_switching/markov_switching.py:1478: EstimationWarning: Invalid regime transition probabilities estimated in EM iteration; probabilities have been re-scaled to continue estimation.
#   EstimationWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/regime_switching/markov_switching.py:1478: EstimationWarning: Invalid regime transition probabilities estimated in EM iteration; probabilities have been re-scaled to continue estimation.
#   EstimationWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/regime_switching/markov_switching.py:1478: EstimationWarning: Invalid regime transition probabilities estimated in EM iteration; probabilities have been re-scaled to continue estimation.
#   EstimationWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/regime_switching/markov_switching.py:1478: EstimationWarning: Invalid regime transition probabilities estimated in EM iteration; probabilities have been re-scaled to continue estimation.
#   EstimationWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/regime_switching/markov_switching.py:1478: EstimationWarning: Invalid regime transition probabilities estimated in EM iteration; probabilities have been re-scaled to continue estimation.
#   EstimationWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:1286: RuntimeWarning: invalid value encountered in sqrt
#   bse_ = np.sqrt(np.diag(self.cov_params()))
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                         Markov Switching Model Results
# ==============================================================================
# Dep. Variable:                log_ret   No. Observations:                 4534
# Model:               MarkovRegression   Log Likelihood               14190.697
# Date:                Mon, 14 Feb 2022   AIC                         -28329.393
# Time:                        21:46:35   BIC                         -28162.490
# Sample:                             0   HQIC                        -28270.605
#                                - 4534
# Covariance Type:               approx
#                              Regime 0 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0607      0.002    -24.746      0.000      -0.066      -0.056
#                              Regime 1 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0048      0.001      4.917      0.000       0.003       0.007
#                              Regime 2 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0320      0.002     20.453      0.000       0.029       0.035
#                              Regime 3 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0006      0.000      3.685      0.000       0.000       0.001
#                              Regime 4 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0208      0.001    -24.189      0.000      -0.022      -0.019
#                            Non-switching parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      7.985e-05   2.64e-06     30.269      0.000    7.47e-05     8.5e-05
#                          Regime transition parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p[0->0]        0.0296        nan        nan        nan         nan         nan
# p[1->0]        0.0796      0.023      3.490      0.000       0.035       0.124
# p[2->0]     1.052e-11        nan        nan        nan         nan         nan
# p[3->0]     1.024e-05      0.001      0.016      0.987      -0.001       0.001
# p[4->0]        0.0703      0.032      2.202      0.028       0.008       0.133
# p[0->1]        0.4459      0.173      2.573      0.010       0.106       0.785
# p[1->1]        0.0688        nan        nan        nan         nan         nan
# p[2->1]        0.5138      0.083      6.207      0.000       0.352       0.676
# p[3->1]        0.0076        nan        nan        nan         nan         nan
# p[4->1]        0.3663        nan        nan        nan         nan         nan
# p[0->2]        0.5212      0.162      3.214      0.001       0.203       0.839
# p[1->2]        0.3352      0.043      7.851      0.000       0.252       0.419
# p[2->2]        0.1225      0.043      2.876      0.004       0.039       0.206
# p[3->2]        0.0003        nan        nan        nan         nan         nan
# p[4->2]        0.1607      0.038      4.248      0.000       0.087       0.235
# p[0->3]        0.0034      0.239      0.014      0.989      -0.465       0.472
# p[1->3]        0.1723        nan        nan        nan         nan         nan
# p[2->3]        0.0083      0.079      0.104      0.917      -0.147       0.164
# p[3->3]        0.9877        nan        nan        nan         nan         nan
# p[4->3]        0.1433      0.074      1.939      0.053      -0.002       0.288
# ==============================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#                         Markov Switching Model Results
# ==============================================================================
# Dep. Variable:                log_ret   No. Observations:                 4534
# Model:               MarkovRegression   Log Likelihood               14603.693
# Date:                Mon, 14 Feb 2022   AIC                         -29147.386
# Time:                        21:47:22   BIC                         -28954.805
# Sample:                             0   HQIC                        -29079.554
#                                - 4534
# Covariance Type:               approx
#                              Regime 0 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0063        nan        nan        nan         nan         nan
# sigma2      2.795e-05        nan        nan        nan         nan         nan
#                              Regime 1 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0081      0.001    -15.193      0.000      -0.009      -0.007
# sigma2      2.136e-05   3.55e-06      6.014      0.000    1.44e-05    2.83e-05
#                              Regime 2 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0017      0.001     -1.396      0.163      -0.004       0.001
# sigma2         0.0007   5.54e-05     12.831      0.000       0.001       0.001
#                              Regime 3 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0004      0.000     -1.334      0.182      -0.001       0.000
# sigma2         0.0001   8.54e-06     16.317      0.000       0.000       0.000
#                              Regime 4 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0006   7.46e-05      7.711      0.000       0.000       0.001
# sigma2      1.298e-05   6.94e-07     18.701      0.000    1.16e-05    1.43e-05
#                          Regime transition parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p[0->0]        0.1827        nan        nan        nan         nan         nan
# p[1->0]        0.5586        nan        nan        nan         nan         nan
# p[2->0]        0.0028        nan        nan        nan         nan         nan
# p[3->0]        0.0377        nan        nan        nan         nan         nan
# p[4->0]        0.1879      0.036      5.257      0.000       0.118       0.258
# p[0->1]        0.0126      0.033      0.381      0.703      -0.052       0.077
# p[1->1]        0.0172      0.039      0.445      0.656      -0.059       0.093
# p[2->1]        0.0022      0.038      0.058      0.954      -0.071       0.076
# p[3->1]        0.0010        nan        nan        nan         nan         nan
# p[4->1]        0.1768      0.029      6.190      0.000       0.121       0.233
# p[0->2]        0.0114        nan        nan        nan         nan         nan
# p[1->2]        0.0026        nan        nan        nan         nan         nan
# p[2->2]        0.9622      0.035     27.888      0.000       0.895       1.030
# p[3->2]        0.0001      0.000      0.356      0.722      -0.000       0.001
# p[4->2]        0.0016        nan        nan        nan         nan         nan
# p[0->3]        0.0073        nan        nan        nan         nan         nan
# p[1->3]        0.2725        nan        nan        nan         nan         nan
# p[2->3]        0.0263      0.013      2.055      0.040       0.001       0.051
# p[3->3]        0.9567      0.011     87.066      0.000       0.935       0.978
# p[4->3]        0.0013        nan        nan        nan         nan         nan
# ==============================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:1286: RuntimeWarning: invalid value encountered in sqrt
#   bse_ = np.sqrt(np.diag(self.cov_params()))

# %% [markdown]
# ## Basic HMM with EWMA5

# %%
hmm1 = sm.tsa.MarkovRegression(endog=df_train['log_ret_EWMA5'], k_regimes=2,trend='c',switching_variance=False)
hmm1_results = hmm1.fit(search_reps = 100)
print(hmm1_results.summary())
hmm1 = sm.tsa.MarkovRegression(endog=df_train['log_ret_EWMA5'], k_regimes=2,trend='c',switching_variance=True)
hmm1_results = hmm1.fit(search_reps = 100)
print(hmm1_results.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                         Markov Switching Model Results
# ==============================================================================
# Dep. Variable:          log_ret_EWMA5   No. Observations:                 4534
# Model:               MarkovRegression   Log Likelihood               17999.957
# Date:                Mon, 14 Feb 2022   AIC                         -35989.913
# Time:                        21:47:25   BIC                         -35957.817
# Sample:                             0   HQIC                        -35978.608
#                                - 4534
# Covariance Type:               approx
#                              Regime 0 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0081      0.000    -22.272      0.000      -0.009      -0.007
#                              Regime 1 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0013   8.76e-05     14.909      0.000       0.001       0.001
#                            Non-switching parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      1.665e-05   4.08e-07     40.804      0.000    1.59e-05    1.75e-05
#                          Regime transition parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p[0->0]        0.7840      0.022     36.308      0.000       0.742       0.826
# p[1->0]        0.0303      0.004      8.093      0.000       0.023       0.038
# ==============================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                         Markov Switching Model Results
# ==============================================================================
# Dep. Variable:          log_ret_EWMA5   No. Observations:                 4534
# Model:               MarkovRegression   Log Likelihood               18452.828
# Date:                Mon, 14 Feb 2022   AIC                         -36893.655
# Time:                        21:47:27   BIC                         -36855.139
# Sample:                             0   HQIC                        -36880.089
#                                - 4534
# Covariance Type:               approx
#                              Regime 0 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0016      0.000     -7.580      0.000      -0.002      -0.001
# sigma2      5.394e-05   2.43e-06     22.198      0.000    4.92e-05    5.87e-05
#                              Regime 1 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0012   7.41e-05     16.055      0.000       0.001       0.001
# sigma2       6.58e-06   3.34e-07     19.689      0.000    5.92e-06    7.23e-06
#                          Regime transition parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p[0->0]        0.9421      0.008    111.698      0.000       0.926       0.959
# p[1->0]        0.0348      0.005      6.706      0.000       0.025       0.045
# ==============================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.

# %%
hmm1 = sm.tsa.MarkovRegression(endog=df_train['log_ret_EWMA5'], k_regimes=3,trend='c',switching_variance=False)
hmm1_results = hmm1.fit(search_reps = 100)
print(hmm1_results.summary())
hmm1 = sm.tsa.MarkovRegression(endog=df_train['log_ret_EWMA5'], k_regimes=3,trend='c',switching_variance=True)
hmm1_results = hmm1.fit(search_reps = 100)
print(hmm1_results.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                         Markov Switching Model Results
# ==============================================================================
# Dep. Variable:          log_ret_EWMA5   No. Observations:                 4534
# Model:               MarkovRegression   Log Likelihood               18314.894
# Date:                Mon, 14 Feb 2022   AIC                         -36609.787
# Time:                        21:47:33   BIC                         -36545.594
# Sample:                             0   HQIC                        -36587.177
#                                - 4534
# Covariance Type:               approx
#                              Regime 0 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0209      0.001    -32.840      0.000      -0.022      -0.020
#                              Regime 1 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0021   8.93e-05     23.477      0.000       0.002       0.002
#                              Regime 2 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0044      0.000    -21.854      0.000      -0.005      -0.004
#                            Non-switching parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      1.238e-05   3.17e-07     39.107      0.000    1.18e-05     1.3e-05
#                          Regime transition parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p[0->0]        0.4744      0.070      6.819      0.000       0.338       0.611
# p[1->0]        0.0009      0.001      1.477      0.140      -0.000       0.002
# p[2->0]        0.0242      0.005      4.784      0.000       0.014       0.034
# p[0->1]        0.1811      0.062      2.932      0.003       0.060       0.302
# p[1->1]        0.9362      0.006    157.944      0.000       0.925       0.948
# p[2->1]        0.1746      0.015     12.024      0.000       0.146       0.203
# ==============================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                         Markov Switching Model Results
# ==============================================================================
# Dep. Variable:          log_ret_EWMA5   No. Observations:                 4534
# Model:               MarkovRegression   Log Likelihood               18868.263
# Date:                Mon, 14 Feb 2022   AIC                         -37712.525
# Time:                        21:47:41   BIC                         -37635.493
# Sample:                             0   HQIC                        -37685.392
#                                - 4534
# Covariance Type:               approx
#                              Regime 0 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0021   7.43e-05     27.667      0.000       0.002       0.002
# sigma2       5.24e-06   2.36e-07     22.203      0.000    4.78e-06     5.7e-06
#                              Regime 1 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0008      0.000     -2.199      0.028      -0.002   -8.97e-05
# sigma2      9.182e-05   5.88e-06     15.622      0.000    8.03e-05       0.000
#                              Regime 2 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0031      0.000    -16.951      0.000      -0.004      -0.003
# sigma2      8.653e-06   5.44e-07     15.910      0.000    7.59e-06    9.72e-06
#                          Regime transition parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p[0->0]        0.9136      0.008    116.052      0.000       0.898       0.929
# p[1->0]        0.0344      0.010      3.565      0.000       0.015       0.053
# p[2->0]        0.1559      0.014     11.125      0.000       0.128       0.183
# p[0->1]     2.509e-06      0.002      0.001      0.999      -0.003       0.003
# p[1->1]        0.9645      0.009    111.618      0.000       0.948       0.981
# p[2->1]        0.0229      0.006      3.844      0.000       0.011       0.035
# ==============================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.

# %%
hmm1 = sm.tsa.MarkovRegression(endog=df_train['log_ret_EWMA5'], k_regimes=4,trend='c',switching_variance=False)
hmm1_results = hmm1.fit(search_reps = 100)
print(hmm1_results.summary())
hmm1 = sm.tsa.MarkovRegression(endog=df_train['log_ret_EWMA5'], k_regimes=4,trend='c',switching_variance=True)
hmm1_results = hmm1.fit(search_reps = 100)
print(hmm1_results.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:1286: RuntimeWarning: invalid value encountered in sqrt
#   bse_ = np.sqrt(np.diag(self.cov_params()))
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                         Markov Switching Model Results
# ==============================================================================
# Dep. Variable:          log_ret_EWMA5   No. Observations:                 4534
# Model:               MarkovRegression   Log Likelihood               18634.650
# Date:                Mon, 14 Feb 2022   AIC                         -37235.300
# Time:                        21:47:59   BIC                         -37126.170
# Sample:                             0   HQIC                        -37196.861
#                                - 4534
# Covariance Type:               approx
#                              Regime 0 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0084      0.000     19.203      0.000       0.008       0.009
#                              Regime 1 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0014   9.31e-05     14.631      0.000       0.001       0.002
#                              Regime 2 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0212      0.001    -31.969      0.000      -0.023      -0.020
#                              Regime 3 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0051      0.000    -21.405      0.000      -0.006      -0.005
#                            Non-switching parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      9.105e-06   2.98e-07     30.555      0.000    8.52e-06    9.69e-06
#                          Regime transition parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p[0->0]        0.7449      0.032     23.121      0.000       0.682       0.808
# p[1->0]        0.0105      0.004      2.795      0.005       0.003       0.018
# p[2->0]        0.0648      0.035      1.859      0.063      -0.004       0.133
# p[3->0]        0.0379      0.012      3.210      0.001       0.015       0.061
# p[0->1]        0.1722      0.043      4.032      0.000       0.088       0.256
# p[1->1]        0.9313      0.007    124.926      0.000       0.917       0.946
# p[2->1]        0.0872      0.044      1.993      0.046       0.001       0.173
# p[3->1]        0.1694      0.022      7.804      0.000       0.127       0.212
# p[0->2]     9.007e-20        nan        nan        nan         nan         nan
# p[1->2]     6.857e-22   5.73e-05    1.2e-17      1.000      -0.000       0.000
# p[2->2]        0.4384      0.071      6.206      0.000       0.300       0.577
# p[3->2]        0.0326      0.006      5.207      0.000       0.020       0.045
# ==============================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.
#                         Markov Switching Model Results
# ==============================================================================
# Dep. Variable:          log_ret_EWMA5   No. Observations:                 4534
# Model:               MarkovRegression   Log Likelihood               18868.244
# Date:                Mon, 14 Feb 2022   AIC                         -37696.489
# Time:                        21:48:20   BIC                         -37568.101
# Sample:                             0   HQIC                        -37651.267
#                                - 4534
# Covariance Type:               approx
#                              Regime 0 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0021   7.45e-05     27.532      0.000       0.002       0.002
# sigma2      5.249e-06   2.38e-07     22.016      0.000    4.78e-06    5.72e-06
#                              Regime 1 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0032      0.000    -16.657      0.000      -0.004      -0.003
# sigma2       8.69e-06   5.62e-07     15.452      0.000    7.59e-06    9.79e-06
#                              Regime 2 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0014        nan        nan        nan         nan         nan
# sigma2      1.213e-05        nan        nan        nan         nan         nan
#                              Regime 3 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0008      0.000     -2.171      0.030      -0.002   -7.94e-05
# sigma2      9.196e-05   5.92e-06     15.529      0.000    8.04e-05       0.000
#                          Regime transition parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p[0->0]        0.9136      0.008    116.281      0.000       0.898       0.929
# p[1->0]        0.1557      0.014     11.108      0.000       0.128       0.183
# p[2->0]        0.5268        nan        nan        nan         nan         nan
# p[3->0]        0.0353      0.010      3.576      0.000       0.016       0.055
# p[0->1]        0.0864      0.008     11.077      0.000       0.071       0.102
# p[1->1]        0.8216      0.015     55.512      0.000       0.793       0.851
# p[2->1]        0.4724        nan        nan        nan         nan         nan
# p[3->1]      1.85e-14      0.006   3.03e-12      1.000      -0.012       0.012
# p[0->2]     3.417e-25        nan        nan        nan         nan         nan
# p[1->2]      1.36e-14        nan        nan        nan         nan         nan
# p[2->2]       9.8e-14        nan        nan        nan         nan         nan
# p[3->2]     2.802e-15        nan        nan        nan         nan         nan
# ==============================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.
# [2] Covariance matrix is singular or near-singular, with condition number 9.71e+17. Standard errors may be unstable.
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:1286: RuntimeWarning: invalid value encountered in sqrt
#   bse_ = np.sqrt(np.diag(self.cov_params()))

# %%
hmm1 = sm.tsa.MarkovRegression(endog=df_train['log_ret_EWMA5'], k_regimes=5,trend='c',switching_variance=False)
hmm1_results = hmm1.fit(search_reps = 100)
print(hmm1_results.summary())
hmm1 = sm.tsa.MarkovRegression(endog=df_train['log_ret_EWMA5'], k_regimes=5,trend='c',switching_variance=True)
hmm1_results = hmm1.fit(search_reps = 100)
print(hmm1_results.summary())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/regime_switching/markov_switching.py:1478: EstimationWarning: Invalid regime transition probabilities estimated in EM iteration; probabilities have been re-scaled to continue estimation.
#   EstimationWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/regime_switching/markov_switching.py:1478: EstimationWarning: Invalid regime transition probabilities estimated in EM iteration; probabilities have been re-scaled to continue estimation.
#   EstimationWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/regime_switching/markov_switching.py:1478: EstimationWarning: Invalid regime transition probabilities estimated in EM iteration; probabilities have been re-scaled to continue estimation.
#   EstimationWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/regime_switching/markov_switching.py:1478: EstimationWarning: Invalid regime transition probabilities estimated in EM iteration; probabilities have been re-scaled to continue estimation.
#   EstimationWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/regime_switching/markov_switching.py:1478: EstimationWarning: Invalid regime transition probabilities estimated in EM iteration; probabilities have been re-scaled to continue estimation.
#   EstimationWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/regime_switching/markov_switching.py:1478: EstimationWarning: Invalid regime transition probabilities estimated in EM iteration; probabilities have been re-scaled to continue estimation.
#   EstimationWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/regime_switching/markov_switching.py:1478: EstimationWarning: Invalid regime transition probabilities estimated in EM iteration; probabilities have been re-scaled to continue estimation.
#   EstimationWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/regime_switching/markov_switching.py:1478: EstimationWarning: Invalid regime transition probabilities estimated in EM iteration; probabilities have been re-scaled to continue estimation.
#   EstimationWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/regime_switching/markov_switching.py:1478: EstimationWarning: Invalid regime transition probabilities estimated in EM iteration; probabilities have been re-scaled to continue estimation.
#   EstimationWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:1286: RuntimeWarning: invalid value encountered in sqrt
#   bse_ = np.sqrt(np.diag(self.cov_params()))
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                         Markov Switching Model Results
# ==============================================================================
# Dep. Variable:          log_ret_EWMA5   No. Observations:                 4534
# Model:               MarkovRegression   Log Likelihood               18667.513
# Date:                Mon, 14 Feb 2022   AIC                         -37283.027
# Time:                        21:48:57   BIC                         -37116.123
# Sample:                             0   HQIC                        -37224.239
#                                - 4534
# Covariance Type:               approx
#                              Regime 0 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0091      0.000     24.489      0.000       0.008       0.010
#                              Regime 1 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0148      0.000    -39.252      0.000      -0.016      -0.014
#                              Regime 2 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0329      0.001    -38.463      0.000      -0.035      -0.031
#                              Regime 3 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0015   8.94e-05     16.950      0.000       0.001       0.002
#                              Regime 4 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0046      0.000    -25.163      0.000      -0.005      -0.004
#                            Non-switching parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      8.512e-06   2.64e-07     32.195      0.000    7.99e-06    9.03e-06
#                          Regime transition parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p[0->0]        0.7242      0.034     21.208      0.000       0.657       0.791
# p[1->0]        0.0084      0.004      1.913      0.056      -0.000       0.017
# p[2->0]     6.425e-06      0.006      0.001      0.999      -0.012       0.012
# p[3->0]        0.0170      0.003      4.893      0.000       0.010       0.024
# p[4->0]        0.0129      0.005      2.393      0.017       0.002       0.023
# p[0->1]        0.0005      0.001      1.003      0.316      -0.001       0.002
# p[1->1]        0.5877      0.064      9.172      0.000       0.462       0.713
# p[2->1]        0.8609      0.058     14.721      0.000       0.746       0.976
# p[3->1]        0.0001      0.000      0.422      0.673      -0.000       0.001
# p[4->1]        0.0318      0.007      4.873      0.000       0.019       0.045
# p[0->2]     3.645e-19   9.95e-13   3.66e-07      1.000   -1.95e-12    1.95e-12
# p[1->2]        0.0584      0.012      4.835      0.000       0.035       0.082
# p[2->2]     8.464e-20        nan        nan        nan         nan         nan
# p[3->2]     5.902e-13      6e-06   9.84e-08      1.000   -1.18e-05    1.18e-05
# p[4->2]        0.0035      0.004      0.977      0.329      -0.003       0.010
# p[0->3]        0.2477      0.037      6.777      0.000       0.176       0.319
# p[1->3]        0.3455      0.056      6.169      0.000       0.236       0.455
# p[2->3]        0.1391      0.060      2.328      0.020       0.022       0.256
# p[3->3]        0.9133      0.007    133.797      0.000       0.900       0.927
# p[4->3]        0.1882      0.017     11.009      0.000       0.155       0.222
# ==============================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#                         Markov Switching Model Results
# ==============================================================================
# Dep. Variable:          log_ret_EWMA5   No. Observations:                 4534
# Model:               MarkovRegression   Log Likelihood               19244.543
# Date:                Mon, 14 Feb 2022   AIC                         -38429.086
# Time:                        21:49:41   BIC                         -38236.506
# Sample:                             0   HQIC                        -38361.254
#                                - 4534
# Covariance Type:               approx
#                              Regime 0 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0016      0.000     -3.297      0.001      -0.003      -0.001
# sigma2         0.0001   6.03e-06     18.019      0.000    9.68e-05       0.000
#                              Regime 1 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0052        nan        nan        nan         nan         nan
# sigma2      5.153e-06        nan        nan        nan         nan         nan
#                              Regime 2 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0002        nan        nan        nan         nan         nan
# sigma2      2.621e-06        nan        nan        nan         nan         nan
#                              Regime 3 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0026        nan        nan        nan         nan         nan
# sigma2      1.827e-06   5.48e-08     33.361      0.000    1.72e-06    1.93e-06
#                              Regime 4 parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0043        nan        nan        nan         nan         nan
# sigma2      9.406e-06   3.86e-07     24.344      0.000    8.65e-06    1.02e-05
#                          Regime transition parameters
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# p[0->0]        0.9666        nan        nan        nan         nan         nan
# p[1->0]        0.0003      0.005      0.068      0.946      -0.009       0.009
# p[2->0]        0.0033      0.006      0.554      0.580      -0.008       0.015
# p[3->0]        0.0005      0.003      0.163      0.870      -0.006       0.007
# p[4->0]        0.0099      0.004      2.765      0.006       0.003       0.017
# p[0->1]        0.0262        nan        nan        nan         nan         nan
# p[1->1]        0.7264        nan        nan        nan         nan         nan
# p[2->1]        0.0563        nan        nan        nan         nan         nan
# p[3->1]        0.0070        nan        nan        nan         nan         nan
# p[4->1]        0.0556        nan        nan        nan         nan         nan
# p[0->2]        0.0006        nan        nan        nan         nan         nan
# p[1->2]        0.0116        nan        nan        nan         nan         nan
# p[2->2]        0.6662      0.017     40.361      0.000       0.634       0.699
# p[3->2]        0.2300      0.021     10.928      0.000       0.189       0.271
# p[4->2]        0.1731        nan        nan        nan         nan         nan
# p[0->3]        0.0012        nan        nan        nan         nan         nan
# p[1->3]        0.2464        nan        nan        nan         nan         nan
# p[2->3]        0.1560      0.008     20.171      0.000       0.141       0.171
# p[3->3]        0.7080        nan        nan        nan         nan         nan
# p[4->3]        0.0087        nan        nan        nan         nan         nan
# ==============================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:1286: RuntimeWarning: invalid value encountered in sqrt
#   bse_ = np.sqrt(np.diag(self.cov_params()))
